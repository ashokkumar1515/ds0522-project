# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
#       free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                   False                 False    False  False      False
# 1                   False                 False    False  False      False
# 2                   False                 False    False  False      False
# 3                   False                 False    False  False      False
# 4                   False                 False    False  False      False
# ...                   ...                   ...      ...    ...        ...
# 1594                False                 False    False  False      False
# 1595                False                 False    False  False      False
# 1596                False                 False    False  False      False
# 1597                False                 False    False  False      False
# 1598                False                 False    False  False      False
#
#       alcohol  quality
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ...       ...      ...
# 1594    False    False
# 1595    False    False
# 1596    False    False
# 1597    False    False
# 1598    False    False
#
# [1599 rows x 12 columns]>

# %%
import seaborn as sns
sns.scatterplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x='alcohol',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x='fixed acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='density',y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="blue",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
plt.figure(figsize=(20,18))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=20)
plt.yticks(fontsize=18)
plt.title("variables summary")
plt.show()

# %%
df.describe()[1:].transpose()
# Out:
#                            mean        std      min      25%       50%  \
# fixed acidity          8.319637   1.741096  4.60000   7.1000   7.90000
# volatile acidity       0.527821   0.179060  0.12000   0.3900   0.52000
# citric acid            0.270976   0.194801  0.00000   0.0900   0.26000
# residual sugar         2.538806   1.409928  0.90000   1.9000   2.20000
# chlorides              0.087467   0.047065  0.01200   0.0700   0.07900
# free sulfur dioxide   15.874922  10.460157  1.00000   7.0000  14.00000
# total sulfur dioxide  46.467792  32.895324  6.00000  22.0000  38.00000
# density                0.996747   0.001887  0.99007   0.9956   0.99675
# pH                     3.311113   0.154386  2.74000   3.2100   3.31000
# sulphates              0.658149   0.169507  0.33000   0.5500   0.62000
# alcohol               10.422983   1.065668  8.40000   9.5000  10.20000
# quality                5.636023   0.807569  3.00000   5.0000   6.00000
#
#                             75%        max
# fixed acidity          9.200000   15.90000
# volatile acidity       0.640000    1.58000
# citric acid            0.420000    1.00000
# residual sugar         2.600000   15.50000
# chlorides              0.090000    0.61100
# free sulfur dioxide   21.000000   72.00000
# total sulfur dioxide  62.000000  289.00000
# density                0.997835    1.00369
# pH                     3.400000    4.01000
# sulphates              0.730000    2.00000
# alcohol               11.100000   14.90000
# quality                6.000000    8.00000

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#                        mean    std   min    25%    50%    75%     max
# fixed acidity          8.32   1.74  4.60   7.10   7.90   9.20   15.90
# volatile acidity       0.53   0.18  0.12   0.39   0.52   0.64    1.58
# citric acid            0.27   0.19  0.00   0.09   0.26   0.42    1.00
# residual sugar         2.54   1.41  0.90   1.90   2.20   2.60   15.50
# chlorides              0.09   0.05  0.01   0.07   0.08   0.09    0.61
# free sulfur dioxide   15.87  10.46  1.00   7.00  14.00  21.00   72.00
# total sulfur dioxide  46.47  32.90  6.00  22.00  38.00  62.00  289.00
# density                1.00   0.00  0.99   1.00   1.00   1.00    1.00
# pH                     3.31   0.15  2.74   3.21   3.31   3.40    4.01
# sulphates              0.66   0.17  0.33   0.55   0.62   0.73    2.00
# alcohol               10.42   1.07  8.40   9.50  10.20  11.10   14.90
# quality                5.64   0.81  3.00   5.00   6.00   6.00    8.00

# %%
sns.heatmap(round(df.describe()[1:].transpose(),2))
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=40
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='red',orient='h')
    plt.tight_layout()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
sns.distplot(df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df["chlorides"])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["density"])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df["pH"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df["sulphates"])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(df["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
df=df.drop(["fixed acidity","citric acid"],axis=1)

# %%
df
# Out:
#       volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0                0.700             1.9      0.076                 11.0
# 1                0.880             2.6      0.098                 25.0
# 2                0.760             2.3      0.092                 15.0
# 3                0.280             1.9      0.075                 17.0
# 4                0.700             1.9      0.076                 11.0
# ...                ...             ...        ...                  ...
# 1594             0.600             2.0      0.090                 32.0
# 1595             0.550             2.2      0.062                 39.0
# 1596             0.510             2.3      0.076                 29.0
# 1597             0.645             2.0      0.075                 32.0
# 1598             0.310             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# 1                     67.0  0.99680  3.20       0.68      9.8        5
# 2                     54.0  0.99700  3.26       0.65      9.8        5
# 3                     60.0  0.99800  3.16       0.58      9.8        6
# 4                     34.0  0.99780  3.51       0.56      9.4        5
# ...                    ...      ...   ...        ...      ...      ...
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# [1599 rows x 10 columns]

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
theshold=3 # rule of thumb
print(np.where(z>3)) # index number
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         163,  164,  169,  169,  181,  199,  226,  226,  240,  258,  258,
#         274,  281,  291,  324,  325,  339,  340,  354,  396,  396,  400,
#         400,  442,  451,  459,  467,  480,  480,  494,  515,  517,  554,
#         555,  557,  568,  584,  588,  591,  595,  608,  614,  636,  639,
#         649,  649,  651,  652,  652,  672,  672,  684,  690,  690,  692,
#         692,  695,  723,  724,  730,  754,  776,  777,  795,  821,  832,
#         836,  837,  889,  899,  911,  917,  923,  925,  926,  982, 1017,
#        1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111,
#        1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244,
#        1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296, 1299, 1299,
#        1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370, 1370, 1372,
#        1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435, 1469, 1474,
#        1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505, 1558, 1558,
#        1570, 1574, 1589], dtype=int64), array([7, 3, 3, 4, 2, 7, 2, 1, 0, 2, 7, 6, 3, 2, 7, 2, 7, 7, 7, 7, 6, 2,
#        7, 4, 0, 0, 0, 8, 8, 2, 2, 6, 7, 1, 1, 2, 7, 2, 0, 2, 7, 2, 2, 7,
#        1, 2, 2, 1, 1, 7, 7, 4, 1, 3, 1, 3, 5, 2, 9, 8, 1, 5, 1, 4, 9, 5,
#        5, 5, 2, 3, 8, 4, 1, 5, 7, 4, 7, 1, 4, 4, 1, 8, 0, 4, 4, 0, 9, 2,
#        7, 6, 7, 0, 2, 2, 2, 2, 7, 8, 9, 5, 5, 5, 9, 1, 1, 1, 3, 3, 3, 5,
#        5, 1, 2, 7, 1, 1, 1, 4, 1, 4, 6, 5, 3, 3, 2, 3, 1, 3, 1, 1, 3, 4,
#        2, 5, 8, 5, 8, 7, 7, 3, 3, 0, 9, 6, 0, 6, 2, 7, 6, 3, 7, 2, 7, 2,
#        7, 2, 9, 1, 3, 5, 1, 3, 5, 9, 1, 3, 5, 1, 3, 5, 9, 4, 4, 9, 2, 3,
#        2, 1, 1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 179

# %%
z.iloc[5]
# Out:
# volatile acidity        0.738418
# residual sugar          0.524166
# chlorides               0.264960
# free sulfur dioxide     0.274931
# total sulfur dioxide    0.196679
# density                 0.558274
# pH                      1.288643
# sulphates               0.579207
# alcohol                 0.960246
# quality                 0.787823
# Name: 5, dtype: float64

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=5
np.where(z>5)
# Out:
# (array([  13,   17,   19,   33,   42,   81,   83,   86,   91,   92,  106,
#          151,  151,  169,  169,  226,  226,  258,  281,  291,  324,  325,
#          451,  480,  692,  723,  730,  754, 1051, 1079, 1081, 1165, 1235,
#         1244, 1244, 1260, 1299, 1319, 1370, 1372, 1434, 1435, 1474, 1476,
#         1574], dtype=int64),
#  array([7, 2, 2, 1, 2, 2, 2, 7, 7, 7, 2, 2, 7, 2, 7, 2, 7, 2, 2, 2, 1, 1,
#         2, 1, 2, 7, 2, 2, 2, 4, 4, 2, 1, 1, 3, 2, 0, 2, 2, 2, 1, 1, 1, 1,
#         1], dtype=int64))

# %%
df_new_z=df[(z<5).all(axis=1)]

# %%
df_new_z
# Out:
#       volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0                0.700             1.9      0.076                 11.0
# 1                0.880             2.6      0.098                 25.0
# 2                0.760             2.3      0.092                 15.0
# 3                0.280             1.9      0.075                 17.0
# 4                0.700             1.9      0.076                 11.0
# ...                ...             ...        ...                  ...
# 1594             0.600             2.0      0.090                 32.0
# 1595             0.550             2.2      0.062                 39.0
# 1596             0.510             2.3      0.076                 29.0
# 1597             0.645             2.0      0.075                 32.0
# 1598             0.310             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# 1                     67.0  0.99680  3.20       0.68      9.8        5
# 2                     54.0  0.99700  3.26       0.65      9.8        5
# 3                     60.0  0.99800  3.16       0.58      9.8        6
# 4                     34.0  0.99780  3.51       0.56      9.4        5
# ...                    ...      ...   ...        ...      ...      ...
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# [1558 rows x 10 columns]

# %%
df_new_z.shape
# Out:
# (1558, 10)

# %%
# percentage loss of data
Data_loss=((1559-1558)/1559)*100

# %%
Data_loss
# Out:
# 0.06414368184733803

# %%
features=df.drop("quality",axis=1)
target=df["quality"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['quality'])
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='quality',y='alcohol',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df)
plt.show()
